# %%
]dev "C:\Users\Christian\Google Drive\github\QuantumStates"
# Out:
#    Resolving package versions...
#     Updating `C:\Users\Christian\.julia\environments\v1.8\Project.toml`
#   [17f0441f] ~ QuantumStates v0.1.0 `G:\My Drive\github\QuantumStates` ⇒ v0.1.0 `C:\Users\Christian\Google Drive\github\QuantumStates`
#     Updating `C:\Users\Christian\.julia\environments\v1.8\Manifest.toml`
#   [17f0441f] ~ QuantumStates v0.1.0 `G:\My Drive\github\QuantumStates` ⇒ v0.1.0 `C:\Users\Christian\Google Drive\github\QuantumStates`

# %%
using QuantumStates
using UnitsToValue
# Out:
# ┌ Info: Precompiling QuantumStates [17f0441f-15e0-42ae-a101-302633ff8f0f]
# └ @ Base loading.jl:1662

# %%
pathof(QuantumStates)
# Out:
# "C:\\Users\\Christian\\Google Drive\\github\\QuantumStates\\src\\QuantumStates.jl"

# %% [markdown]
# ### Load $X(v=0)$ Hamiltonian for $N \in [0,3]$

# %%
H0 = load_from_file("CaF_v0_N0to3_Hamiltonian", "G://My Drive//github//QuantumStates//Hamiltonians//CaF//")
;

# %%
const μX = 1e-6 * 3.07 * (1e-21 / c) / h;

# %%
import QuantumStates: polarizability, Zeeman

# Add AC Stark shifts from trap
w = 25e-6; P = 13.25; I_trap = 2P / (π * w^2);
const α = [3.37471e-39, 0, -1.01809e-39] # 1064 nm
const θ = 0 * (π / 2)
const ϵ_trap = cos(θ) * [0.0, 1.0, 0.0] + sin(θ) * [1.0, 0.0, -1.0] / √2
polarizability(state, state′) = polarizability(state, state′, α, ϵ_trap)
@time H = add_to_H(H0, :I_trap, (1e-6 / h) * polarizability)

# Optical pumping trap, perpendicular to B-field
# const θ = π / 2. # 45 degrees
# const ϵ_trap = cos(θ) * [0.0, 1.0, 0.0] + sin(θ) * [1.0, 0.0, -1.0] / √2
# polarizability(state, state′) = polarizability(state, state′, α, ϵ_trap)
# @time H = add_to_H(H0, :I_trap, (1e-6 / h) * polarizability)

# Add Zeeman terms for a B-fields along x, y, and z
Zeeman_x(state, state′) = (1/√2)  * (Zeeman(state, state′, -1) - Zeeman(state, state′, +1))
Zeeman_y(state, state′) = (im/√2) * (Zeeman(state, state′, -1) + Zeeman(state, state′, +1))
Zeeman_z(state, state′) = Zeeman(state, state′, 0)
H = add_to_H(H, :B_x, gS * (μ_B / h) * 1e-10 * Zeeman_x)
H = add_to_H(H, :B_y, gS * (μ_B / h) * 1e-10 * Zeeman_y)
H = add_to_H(H, :B_z, gS * (μ_B / h) * 1e-10 * Zeeman_z)

# Evaluate and solve the Hamiltonian
H.parameters.I_trap = I_trap / (2ε_0 * c)
H.parameters.B_z = 0e-3
H.parameters.B_x = 0.
@time full_evaluate!(H)
@time solve!(H)
;
# Out:
#   0.082436 seconds (15.21 k allocations: 1.071 MiB, 22.61% compilation time: 100% of which was recompilation)
# WARNING: redefinition of constant α. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant ϵ_trap. This may fail, cause incorrect answers, or produce other errors.
#   0.171062 seconds (118.85 k allocations: 10.211 MiB, 50.86% compilation time: 100% of which was recompilation)
#   0.031801 seconds (744 allocations: 1.273 MiB)

# %%
H.states[12] |> energy
# Out:
# 20643.32107849599

# %%
H.states[16] |> energy
# Out:
# 20644.90051152439

# %% [markdown]
# ### Zeeman plots for $B_x$ (and $B_z = 10~\text{mG}$)

# %%
function H_func!(H, scan_values)
    H.parameters.B_x = scan_values[1]
    evaluate!(H)
    solve!(H)
    return nothing
end
;

# %%
H.parameters.I_trap = I_trap / (2ε_0 * c)
H.parameters.B_z = 0e-3
Bs = (0:0.2:40)
scan_params = (
    B_x = Bs,
    );
iterator = Iterators.product
@time scan_values, _ = scan_parameters(deepcopy(H), scan_params, iterator, H_func!, H -> energy.(H.states), n_threads=1)
matrix_values = hcat(values(scan_values)...)'
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:09
#  10.492913 seconds (7.69 M allocations: 665.041 MiB, 1.10% gc time, 23.58% compilation time)

# %%
using Plots, LaTeXStrings
Es_rel = matrix_values #.- matrix_values[1,:]'
plot(Bs, Es_rel[:,8:16], linewidth=1.5)
plot!(
    legend=nothing,
    xlabel="B (G)",
    ylabel="Energy (MHz)",
    labelfontsize=12,
    tickfontsize=12,
    grid=:off,
    box=:on
    )
