# %%
using QuantumStates
using UnitsToValue

# %% [markdown]
# ### Load $X(v=0)$ Hamiltonian for $N \in [0,3]$

# %%
H0 = load_from_file("CaF_v0_N0to3_Hamiltonian", "G://My Drive//github//QuantumStates//Hamiltonians//CaF//")
;

# %%
const μX = 1e-6 * 3.07 * (1e-21 / c) / h;

# %%
import QuantumStates: polarizability, Zeeman

# Add AC Stark shifts from trap
w = 25e-6; P = 13.25; I_trap = 2P / (π * w^2);
const α = [3.37471e-39, 0, -1.01809e-39] # 1064 nm
const θ = 0 * (π / 2)
const ϵ_trap = cos(θ) * [0.0, 1.0, 0.0] + sin(θ) * [1.0, 0.0, -1.0] / √2
polarizability(state, state′) = polarizability(state, state′, α, ϵ_trap)
@time H = add_to_H(H0, :I_trap, (1e-6 / h) * polarizability)

# Add Zeeman terms for a B-fields along x, y, and z
Zeeman_x(state, state′) = (1/√2)  * (Zeeman(state, state′, -1) - Zeeman(state, state′, +1))
Zeeman_y(state, state′) = (im/√2) * (Zeeman(state, state′, -1) + Zeeman(state, state′, +1))
Zeeman_z(state, state′) = Zeeman(state, state′, 0)
H = add_to_H(H, :B_x, gS * (μ_B / h) * 1e-10 * Zeeman_x)
H = add_to_H(H, :B_y, gS * (μ_B / h) * 1e-10 * Zeeman_y)
H = add_to_H(H, :B_z, gS * (μ_B / h) * 1e-10 * Zeeman_z)

# Add Stark shift terms
H = add_to_H(H, :E_z, μX * Stark)

# Evaluate and solve the Hamiltonian
H.parameters.I_trap = 0.0
H.parameters.B_z = 0.6
H.parameters.E_z = 30000
H.parameters.B_x = 0.0
@time full_evaluate!(H)
@time solve!(H)
;
# Out:
#   0.081889 seconds (15.22 k allocations: 1.072 MiB, 22.65% compilation time: 100% of which was recompilation)
# WARNING: redefinition of constant α. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant ϵ_trap. This may fail, cause incorrect answers, or produce other errors.
#   0.177207 seconds (120.11 k allocations: 10.908 MiB, 49.27% compilation time: 100% of which was recompilation)
#   0.007921 seconds (744 allocations: 1.273 MiB)

# %% [markdown]
# ### Zeeman plots for $B_x$ (and $B_z = 10~\text{mG}$)

# %%
function H_func!(H, scan_values)
    H.parameters.B_z = scan_values[1]
    evaluate!(H)
    solve!(H)
    return nothing
end
;

# %%
Bs = (0:0.1:1)
scan_params = (
    B = Bs,
    );
iterator = Iterators.product
@time scan_values, _ = scan_parameters(deepcopy(H), scan_params, iterator, H_func!, H -> energy.(H.states), n_threads=1)
matrix_values = hcat(values(scan_values)...)'
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
#   0.576510 seconds (185.73 k allocations: 47.266 MiB, 25.56% compilation time)

# %%
using Plots, LaTeXStrings
plot(Bs, matrix_values[:,12:16], linewidth=1.5)
plot!(
    legend=nothing,
    xlabel="B (G)",
    ylabel="Energy (MHz)",
    labelfontsize=12,
    tickfontsize=12,
    grid=:off,
    box=:on
    )

# %%
H.states[16]
# Out:
# State{HundsCaseB_Rot}(20658.121911190403, HundsCaseB_Rot[HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 0, 1/2, 0, 0, (N = 0:∞, J = 0.5:1.0:0.5, F = 0.0:1.0:1.0, M = 0.0:1.0:0.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 0, 1/2, 1, -1, (N = 0:∞, J = 0.5:1.0:0.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 0, 1/2, 1, 0, (N = 0:∞, J = 0.5:1.0:0.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 0, 1/2, 1, 1, (N = 0:∞, J = 0.5:1.0:0.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 1, 1/2, 0, 0, (N = 0:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = 0.0:1.0:0.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 1, 1/2, 1, -1, (N = 0:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 1, 1/2, 1, 0, (N = 0:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 1, 1/2, 1, 1, (N = 0:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 1, 3/2, 1, -1, (N = 0:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 1, 3/2, 1, 0, (N = 0:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -1.0:1.0:1.0))  …  HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, -3, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, -2, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, -1, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 0, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 1, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 2, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 3, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 4, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 5, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 6, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0))], ComplexF64[-6.817832285257267e-6 - 0.0im, 4.012912751764488e-14 - 0.0im, -0.010745147695118687 - 0.0im, -5.335141125740203e-15 - 0.0im, -0.020290835670919948 - 0.0im, -1.921806809481037e-13 - 0.0im, -0.0022278894517753474 - 0.0im, -1.3824042771052558e-13 - 0.0im, -2.0682833436761786e-13 - 0.0im, -0.0009363477776524456 - 0.0im  …  -4.078628556676856e-37 - 0.0im, 1.6508296779779942e-23 - 0.0im, -4.41823222390097e-23 - 0.0im, 1.2178431874516132e-11 - 0.0im, 4.0338784355985124e-24 - 0.0im, 3.9282621916084546e-26 - 0.0im, 3.900016733915031e-38 - 0.0im, 1.364915937150906e-41 - 0.0im, 4.2591797768857923e-85 - 0.0im, -0.0 - 0.0im], 16)

# %%
H.states[15]
# Out:
# State{HundsCaseB_Rot}(20657.755468692663, HundsCaseB_Rot[HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 0, 1/2, 0, 0, (N = 0:∞, J = 0.5:1.0:0.5, F = 0.0:1.0:1.0, M = 0.0:1.0:0.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 0, 1/2, 1, -1, (N = 0:∞, J = 0.5:1.0:0.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 0, 1/2, 1, 0, (N = 0:∞, J = 0.5:1.0:0.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 0, 1/2, 1, 1, (N = 0:∞, J = 0.5:1.0:0.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 1, 1/2, 0, 0, (N = 0:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = 0.0:1.0:0.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 1, 1/2, 1, -1, (N = 0:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 1, 1/2, 1, 0, (N = 0:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 1, 1/2, 1, 1, (N = 0:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 1, 3/2, 1, -1, (N = 0:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 1, 3/2, 1, 0, (N = 0:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -1.0:1.0:1.0))  …  HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, -3, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, -2, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, -1, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 0, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 1, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 2, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 3, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 4, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 5, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 6, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0))], ComplexF64[-6.613415553928609e-17 - 0.0im, -5.920348668435612e-13 - 0.0im, 2.984773199774042e-14 - 0.0im, -0.009725704410036373 - 0.0im, 1.4440797417998036e-13 - 0.0im, 2.3683694186064387e-12 - 0.0im, 3.126591986203164e-14 - 0.0im, -0.043958666277667854 - 0.0im, 2.6403968875894435e-12 - 0.0im, 2.8245521749611255e-14 - 0.0im  …  3.7474316960999795e-24 - 0.0im, 4.7635774307234825e-20 - 0.0im, 1.5716643580542003e-16 - 0.0im, -3.3224343872424613e-16 - 0.0im, 1.072122931174258e-11 - 0.0im, -1.5883726211404236e-19 - 0.0im, 6.250917625402319e-26 - 0.0im, -1.435569917951587e-28 - 0.0im, 4.0562383181645633e-72 - 0.0im, -0.0 - 0.0im], 15)

# %%
H.states[14]
# Out:
# State{HundsCaseB_Rot}(20657.212560150903, HundsCaseB_Rot[HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 0, 1/2, 0, 0, (N = 0:∞, J = 0.5:1.0:0.5, F = 0.0:1.0:1.0, M = 0.0:1.0:0.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 0, 1/2, 1, -1, (N = 0:∞, J = 0.5:1.0:0.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 0, 1/2, 1, 0, (N = 0:∞, J = 0.5:1.0:0.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 0, 1/2, 1, 1, (N = 0:∞, J = 0.5:1.0:0.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 1, 1/2, 0, 0, (N = 0:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = 0.0:1.0:0.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 1, 1/2, 1, -1, (N = 0:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 1, 1/2, 1, 0, (N = 0:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 1, 1/2, 1, 1, (N = 0:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 1, 3/2, 1, -1, (N = 0:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 1, 3/2, 1, 0, (N = 0:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -1.0:1.0:1.0))  …  HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, -3, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, -2, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, -1, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 0, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 1, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 2, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 3, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 4, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 5, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 6, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0))], ComplexF64[2.0061848018303323e-18 - 0.0im, -0.009601053792283822 - 0.0im, -1.2989880417234262e-15 - 0.0im, -3.443919456424661e-13 - 0.0im, -1.1632461666673882e-14 - 0.0im, 0.031121382087215085 - 0.0im, -1.904242336746352e-15 - 0.0im, -1.433325463868046e-12 - 0.0im, 0.038360065060570187 - 0.0im, -1.5094538036463405e-15 - 0.0im  …  -2.5909875065295154e-24 - 0.0im, 7.258139383534724e-19 - 0.0im, 1.0729486317636772e-11 - 0.0im, -1.0379125156713281e-16 - 0.0im, 7.633856558563483e-18 - 0.0im, 3.8246508323892656e-19 - 0.0im, 2.1923795267663884e-25 - 0.0im, 4.603190885964873e-28 - 0.0im, -1.7804473156731477e-62 - 0.0im, -0.0 - 0.0im], 14)

# %%
H.states[13]
# Out:
# State{HundsCaseB_Rot}(20656.84794615113, HundsCaseB_Rot[HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 0, 1/2, 0, 0, (N = 0:∞, J = 0.5:1.0:0.5, F = 0.0:1.0:1.0, M = 0.0:1.0:0.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 0, 1/2, 1, -1, (N = 0:∞, J = 0.5:1.0:0.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 0, 1/2, 1, 0, (N = 0:∞, J = 0.5:1.0:0.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 0, 1/2, 1, 1, (N = 0:∞, J = 0.5:1.0:0.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 1, 1/2, 0, 0, (N = 0:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = 0.0:1.0:0.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 1, 1/2, 1, -1, (N = 0:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 1, 1/2, 1, 0, (N = 0:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 1, 1/2, 1, 1, (N = 0:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 1, 3/2, 1, -1, (N = 0:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 1, 3/2, 1, 0, (N = 0:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -1.0:1.0:1.0))  …  HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, -3, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, -2, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, -1, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 0, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 1, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 2, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 3, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 4, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 5, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 0, 5, 11/2, 6, 6, (N = 0:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0))], ComplexF64[7.708765356688089e-18 + 0.0im, 1.3025815096211828e-12 + 0.0im, 1.7258254013893048e-16 + 0.0im, -1.7875356805627093e-13 + 0.0im, -8.641180968168388e-16 + 0.0im, -4.21553722329596e-12 + 0.0im, -9.480609653932952e-16 + 0.0im, -9.673038660716346e-13 + 0.0im, -5.199089998250596e-12 + 0.0im, -1.3987021319548806e-15 + 0.0im  …  3.679244122342126e-24 + 0.0im, -8.599512706927923e-19 + 0.0im, -1.7523079958213603e-16 + 0.0im, 4.49267135710516e-17 + 0.0im, -1.0409047819139987e-17 + 0.0im, 6.794012064660086e-12 + 0.0im, 5.865418380284552e-27 + 0.0im, -6.478660875185024e-28 + 0.0im, 2.505396030005173e-62 + 0.0im, 0.0 + 0.0im], 13)

# %%
TDM(H.states[16], H.states[15], -1)
# Out:
# -0.001592382310211147 + 0.0im

# %% [markdown]
# # Scan AC Stark shift

# %%
function H_func!(H, scan_values)
    H.parameters.I_trap = scan_values[1]
    evaluate!(H)
    solve!(H)
    return nothing
end
;

# %%
Is = (0:0.1:1.0) .* I_trap / (2ε_0 * c)
scan_params = (
    I = Is,
    );
iterator = Iterators.product
@time scan_values, _ = scan_parameters(deepcopy(H), scan_params, iterator, H_func!, H -> energy.(H.states), n_threads=1)
matrix_values = hcat(values(scan_values)...)'
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
#   0.565188 seconds (185.69 k allocations: 47.255 MiB, 25.86% compilation time)

# %%
using Plots, LaTeXStrings
plot(Bs, matrix_values[:,12:16], linewidth=1.5)
plot!(
    legend=nothing,
    xlabel="B (G)",
    ylabel="Energy (MHz)",
    labelfontsize=12,
    tickfontsize=12,
    grid=:off,
    box=:on
    )
