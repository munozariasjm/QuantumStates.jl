# %%
using QuantumStates
using UnitsToValue

# %% [markdown]
# ### Load $X(01^10)$ Hamiltonian

# %%
H0 = load_from_file("CaOH_000_N0to3_Hamiltonian", "G://My Drive//github//QuantumStates//Hamiltonians//CaOH//")
;

# %%
const μX = 1e-6 * 1.458 * (1e-21 / c) / h;

# %%
import QuantumStates: polarizability, Zeeman

# w = 25e-6; P = 13.25; I_trap = 2P / (π * w^2);
# const α = [3.37471e-39, 0, -1.01809e-39] # 1064 nm
# const θ = 0 * (π / 2)
# const ϵ_trap = cos(θ) * [0.0, 1.0, 0.0] + sin(θ) * [1.0, 0.0, -1.0] / √2
# polarizability(state, state′) = polarizability(state, state′, α, ϵ_trap)
# @time H = add_to_H(H0, :I_trap, (1e-6 / h) * polarizability)

# @time H = add_to_H(H0, :E, (1e2 * μX) * Stark) # 1e2 converts from V/m to V/cm

# const B_x = [1.0, 0.0, -1.0] ./ √2
# const B_z = [0.0, 1.0, 0.0]
# Zeeman_x(state, state′) = (1/√2)  * (Zeeman(state, state′, -1) - Zeeman(state, state′, +1))
# Zeeman_y(state, state′) = (im/√2) * (Zeeman(state, state′, -1) + Zeeman(state, state′, +1))
Zeeman_z(state, state′) = Zeeman(state, state′, 0)
# H = add_to_H(H, :B_x, gS * μ_B * Zeeman_x)
# H = add_to_H(H, :B_y, gS * μ_B * Zeeman_y)
# H = add_to_H(H, :B_z, gS * μ_B * Zeeman_z)
H = add_to_H(H0, :B_z, gS * (1e-4 * μ_B / h) * Zeeman_z)

# H.parameters.I_trap = (1.0 / 3.5) * I_trap / (2ε_0 * c)
H.parameters.E = 500. #198 * 0.3
# H.parameters.B_x = 0.0
H.parameters.B_z = 1e-3

@time full_evaluate!(H)
@time solve!(H)
;
# Out:
#   0.244276 seconds (277.39 k allocations: 16.461 MiB, 95.83% compilation time)
#   0.062038 seconds (27.97 k allocations: 3.021 MiB, 27.19% compilation time)

# %% [markdown]
# ### Zeeman plot

# %%
function H_func!(H, scan_values)
    H.parameters.B_z = scan_values[1]
    evaluate!(H)
    QuantumStates.solve!(H)
    return nothing
end
;

# %%
Bs = 0:1:10
x = scan_single_parameter(deepcopy(H), :I_trap, I_trap_scan_range);
# Out:
# UndefVarError: ε0 not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[409]:1
#  [2] eval
#    @ .\boot.jl:368 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1428

# %%
plot_values = zeros(length(I_trap_scan_range), length(H.states))
for (i, I_trap_value) ∈ enumerate(sort(collect(keys(x.state_dict))))
    plot_values[i,:] = energy.(x.state_dict[I_trap_value])
end
# Out:
# UndefVarError: I_trap_scan_range not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[410]:1
#  [2] eval
#    @ .\boot.jl:368 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1428

# %%
plot(I_trap_scan_range, plot_values[:,1:24], legend=nothing)
# Out:
# UndefVarError: plot_values not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[128]:1
#  [2] eval
#    @ .\boot.jl:368 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1428

# %% [markdown]
# ### Electric field scan

# %%
using LaTeXStrings

# %%
function H_func!(H, scan_values)
    H.parameters.E = scan_values[1]
    evaluate!(H)
    QuantumStates.solve!(H)
    return nothing
end
;

# %%
Es = 0:2.:500
# Es = exp.(0:0.05:15)
scan_params = (
    E = Es,
    );
iterator = Iterators.product
@time scan_values, _ = scan_parameters(deepcopy(H), scan_params, iterator, H_func!, H -> energy.(H.states), n_threads=1)
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:14
#  15.021256 seconds (509.99 k allocations: 1.334 GiB, 0.45% gc time, 1.06% compilation time)

# %%
matrix_values = hcat(values(scan_values)...)';

# %%
matrix_values_bending = hcat(values(scan_values)...)';

# %%
energy.(H.states)
# Out:
# 280-element Vector{Float64}:
#    9957.150084830077
#    9957.1500866936
#    9957.150088557391
#    9958.524420876962
#    9983.056767379807
#    9983.056771743384
#    9983.0567761072
#    9984.832266598223
#    9984.832269098244
#    9984.832271597803
#    9984.832274098157
#    9984.832276597785
#   10000.206277639718
#       ⋮
#  290307.0866178246
#  290307.0866186579
#  290307.0866194913
#  290307.08662032476
#  290307.086621158
#  290307.08662199124
#  290307.08662282454
#  290307.08662365796
#  290307.0866244913
#  290307.08662532456
#  290307.08662615775
#  290307.0866269912

# %%
H.states[6]
# Out:
# State{HundsCaseB_Rot}(9983.056771743384, HundsCaseB_Rot[HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 1/2, 0, 0, (N = 1:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = 0.0:1.0:0.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 1/2, 1, -1, (N = 1:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 1/2, 1, 0, (N = 1:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 1/2, 1, 1, (N = 1:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 3/2, 1, -1, (N = 1:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 3/2, 1, 0, (N = 1:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 3/2, 1, 1, (N = 1:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 3/2, 2, -2, (N = 1:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -2.0:1.0:2.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 3/2, 2, -1, (N = 1:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -2.0:1.0:2.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 3/2, 2, 0, (N = 1:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -2.0:1.0:2.0))  …  HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, -3, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, -2, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, -1, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, 0, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, 1, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, 2, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, 3, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, 4, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, 5, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, 6, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0))], ComplexF64[1.3786564125352834e-7 + 0.0im, -3.241852759985816e-8 + 0.0im, -0.03130406711444281 + 0.0im, 2.5647911131065156e-9 + 0.0im, -7.315600263062595e-7 + 0.0im, -0.7064134616043608 + 0.0im, 5.787786513491748e-8 + 0.0im, -7.247411513498886e-14 + 0.0im, 3.176031425600094e-12 + 0.0im, 5.799111570008248e-7 + 0.0im  …  2.540888005027375e-18 + 0.0im, -7.24117956499451e-18 + 0.0im, -1.2836321575809167e-17 + 0.0im, -1.1983083035095866e-16 + 0.0im, 1.5541719248135898e-17 + 0.0im, -8.110528258490113e-17 + 0.0im, 3.541453438293447e-21 + 0.0im, 0.0 + 0.0im, 2.5069766204053254e-19 + 0.0im, 0.0 + 0.0im], 6)

# %%
H.states[12]
# Out:
# State{HundsCaseB_Rot}(9975.528536942935, HundsCaseB_Rot[HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 1/2, 0, 0, (N = 1:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = 0.0:1.0:0.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 1/2, 1, -1, (N = 1:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 1/2, 1, 0, (N = 1:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 1/2, 1, 1, (N = 1:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 3/2, 1, -1, (N = 1:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 3/2, 1, 0, (N = 1:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 3/2, 1, 1, (N = 1:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 3/2, 2, -2, (N = 1:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -2.0:1.0:2.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 3/2, 2, -1, (N = 1:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -2.0:1.0:2.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 3/2, 2, 0, (N = 1:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -2.0:1.0:2.0))  …  HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, -3, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, -2, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, -1, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, 0, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, 1, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, 2, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, 3, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, 4, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, 5, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, 6, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0))], ComplexF64[0.4008205667112323 + 0.0im, 1.9089582368824493e-11 - 0.0im, 0.04650091260963346 + 0.0im, 1.2895282998780534e-10 + 0.0im, 1.6072852383782072e-11 - 0.0im, 0.01618369298067921 + 0.0im, 8.107814458754996e-11 + 0.0im, 8.154528135165082e-19 + 0.0im, 2.792203222525625e-11 + 0.0im, -0.5804397106368957 + 0.0im  …  -4.217694681734382e-17 + 0.0im, -8.854353035004422e-18 + 0.0im, 5.5007615976217457e-17 + 0.0im, 2.435530176427867e-12 + 0.0im, -1.859482679430749e-17 + 0.0im, 6.939363332886387e-17 + 0.0im, -2.3600920015104525e-17 + 0.0im, 0.0 + 0.0im, 7.441173274690759e-18 + 0.0im, 0.0 + 0.0im], 12)

# %%
H.states[3]
# Out:
# State{HundsCaseB_Rot}(9802.552545188682, HundsCaseB_Rot[HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 1/2, 0, 0, (N = 1:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = 0.0:1.0:0.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 1/2, 1, -1, (N = 1:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 1/2, 1, 0, (N = 1:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 1/2, 1, 1, (N = 1:∞, J = 0.5:1.0:1.5, F = 0.0:1.0:1.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 3/2, 1, -1, (N = 1:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 3/2, 1, 0, (N = 1:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 3/2, 1, 1, (N = 1:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -1.0:1.0:1.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 3/2, 2, -2, (N = 1:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -2.0:1.0:2.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 3/2, 2, -1, (N = 1:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -2.0:1.0:2.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, -1, 1, 3/2, 2, 0, (N = 1:∞, J = 0.5:1.0:1.5, F = 1.0:1.0:2.0, M = -2.0:1.0:2.0))  …  HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, -3, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, -2, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, -1, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, 0, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, 1, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, 2, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, 3, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, 4, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, 5, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0)), HundsCaseB_Rot(0.0, 1/2, 1/2, 1, 5, 11/2, 6, 6, (N = 1:∞, J = 4.5:1.0:5.5, F = 5.0:1.0:6.0, M = -6.0:1.0:6.0))], ComplexF64[0.39801114130885823 - 0.0im, 7.006327949907865e-14 + 0.0im, -0.45318992053407886 + 0.0im, -1.2510663730400034e-13 + 0.0im, -4.227544197003828e-14 + 0.0im, -0.2727469361090928 + 0.0im, -5.213767224429594e-14 + 0.0im, 5.962705474217529e-18 + 0.0im, -4.387167639070432e-14 + 0.0im, 0.2484389320744731 + 0.0im  …  2.4920265173593152e-17 + 0.0im, -1.8043284911354905e-17 + 0.0im, 6.186260203282603e-17 + 0.0im, 1.0264386613031596e-12 + 0.0im, 9.21092151809293e-17 + 0.0im, -2.212374058916527e-17 + 0.0im, -2.9701994875121746e-17 + 0.0im, 0.0 + 0.0im, -6.363674832383326e-18 + 0.0im, 0.0 + 0.0im], 3)

# %%
using Plots
using Plots.PlotMeasures
xs = collect(Es)
ys = matrix_values[:,3] .- 10000
plot(xs[1:end-1][2:end], differences_derivative(xs, ys)[2:end,:] .* 1.458^2, linewidth=1.5, linecolor=:green, alpha=0.3)
plot!(xs, ys ./ 250, linewidth=1.5, linecolor=:blue, alpha=0.5)
plot!(
    legend=nothing, 
    # size=(1400,700),
    xlabel="Electric field (V/cm)",
    ylabel="Energy (MHz)",
    labelfontsize=13,
    tickfontsize=13,
    grid=:off,
    box=:on,
    # ylim=(-250,250),
    title=L"Stark shifts for CaOH, $\ell = 1$ bending mode",
    yticks=-0.8:0.4:0.8
    )
plot!(twinx(),color=:red,xticks=:none,label="right",yticks=0.0:0.99/4:0.99,tickfontsize=13)

# %%
using Plots
using Plots.PlotMeasures
xs = collect(Es)
ys = matrix_values[:,1:24]
ys1 = matrix_values_bending[:,1:24];
plot(xs[1:end-1][2:end], -differences_derivative(xs, ys1)[2:end,:] .* 1.458, linewidth=1.5, linecolor=:green, alpha=0.3)
plot!(xs[1:end-1][2:end], -differences_derivative(xs, ys)[2:end,:] .* 1.458, linewidth=1.5, linecolor=:red, alpha=0.3)
# plot!(xs, ys ./ 450000, linewidth=1.5, linecolor=:blue, alpha=0.5)
plot!(
    legend=nothing, 
    # size=(1400,700),
    labelfontsize=13,
    tickfontsize=13,
    xlim=(1,400000),
    grid=:off,
    box=:on,
    ylim=(-1,1),
    # ylim=(-250,250),
    xaxis=:log,
    xticks=(exp10.(0:6), ["1","10",L"100",L"10^3",L"10^4","10^5","10^6"])
    )

# %%
function differences_derivative(xs, ys)
    ys_diff = ys[2:end,:] .- ys[1:end-1,:]
    xs_diff = xs[2:end] - xs[1:end-1]
    return ys_diff ./ xs_diff
end;

# %%
using Plots
plot(xs[1:end-1][2:end], differences_derivative(xs, ys)[2:end,:] * 1.486, linewidth=2)
plot!(
    legend=nothing, 
    # size=(1400,700),
    xlabel="Electric field (V/cm)",
    ylabel="Dipole moment (debye)",
    title=L"Dipole moment in $\widetilde{X}(01^10)$"
    )

# %% [markdown]
# ### Decoupled basis

# %%
H.parameters.E = 62.0
H.parameters.B_z = 0.0
evaluate!(H); solve!(H);

# %%
QN_bounds = (S = 1/2, I = 1/2, Λ = [-1,1], N = 1:3)
basis_decoupled = enumerate_states(HundsCaseB_Decoupled, QN_bounds)
states_decoupled = convert_basis(x.state_dict[62], basis_decoupled)
;

# %%
expectation(states_decoupled[subspace(H.states, (N=1,))[1][14]], :M_S)
# Out:
# 0.005600369479115385 + 0.0im

# %% [markdown]
# In this basis, the first-order Stark shifts are given by the product $\Lambda M_N$:

# %%
idxs = subspace(states_decoupled, (M_N = 0,))[1];

# %% [markdown]
# ### Magnetic field scan

# %%
using Plots.PlotMeasures
# Out:
# WARNING: using PlotMeasures.h in module Main conflicts with an existing identifier.
# WARNING: using PlotMeasures.w in module Main conflicts with an existing identifier.

# %%
H.parameters
# Out:
# ParameterList(Dict(:B_y => 0.0, :cX => 2.053, :I_trap => 7.26354298635441e11, :DX => 0.0117818435994, :BX => 9996.819345976399, :B_z => 0.00101, :γX => 35.4954270272, :B_x => 0.0, :qX => 21.52809640898, :bFX => 2.602…))

# %%
H.parameters.E = 0.0
evaluate!(H) 
solve!(H)
states_idxs = subspace(H.states, (N=1,))[1]
;

# %%
Es = 0.0:0.1:65
g_factors = scan_single_parameter_gfactor(H, :E, Es);

# %%
Es[600] / 0.3
# Out:
# 199.66666666666666

# %%
g_factors[600,14]
# Out:
# 6.96036295266822e-8

# %%
g_factors[645,19]
# Out:
# -1.0757503332570195e-7

# %%
Es[645] / 0.3
# Out:
# 214.66666666666669

# %%
plot(g_factors[2:end, states_idxs[18:19]] ./ maximum(g_factors), linewidth=2)
plot!(
    legend=nothing,
    xlabel="Electric field (V/cm)",
    ylabel=L"g-factor ($\mu_B$)",
    title=L"'Zero g-factor' states in $\widetilde{X}(01^10)$",
    margin=3mm
    )

# %% [markdown]
# ### Plot $\langle \Sigma \rangle$ versus electric field E

# %%
H.parameters.E = 0.0
H.parameters.B = 0.0
evaluate!(H)
solve!(H)

# %%
plot_values = zeros(length(E_scan_range), length(H.states))
for (i, E_value) ∈ enumerate(sort(collect(keys(x.state_dict))))
    plot_values[i,:] = Σ.(x.state_dict[E_value])
end

# %%
xs = collect(E_scan_range)
ys = plot_values[:,1:24]
plot(xs, ys, linewidth=2)
plot!(
    legend=nothing,
    # size=(1400,700),
    xlabel="Electric field (V/cm)",
    ylabel=L"\langle \Sigma \rangle",
    title=L"EDM Sensitivity in CaOH $\widetilde{X}(01^10)$"
    )
