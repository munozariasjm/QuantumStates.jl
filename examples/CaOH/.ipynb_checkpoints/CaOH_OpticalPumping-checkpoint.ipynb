# %%
using QuantumStates, UnitsToValue, DataFrames, PrettyTables

# %% [markdown]
# ### Load Hamiltonian

# %%
H = load_from_file("CaOH_BendingMode_Hamiltonian", "C://Google Drive//github//QuantumStates//Hamiltonians//CaOH//")

# Add AC Stark effect from trap
au = 1.64877727436e-41

# ODT
# w = 25e-6; P = @with_unit 13.25 "W"; I_trap = 2P / (π * w^2);
# α_par = 142.6
# α_perp = 234.6

# Tweezer
w = 2.0e-6; P = @with_unit 0.130 "W"; I_trap = 2P / (π * w^2);
α_par = 186.5
α_perp = 393.2

const α = [(1/3)*(α_par + 2α_perp), 0, (2/3)*(α_par - α_perp)] .* au
const θ = π/2
const ϵ_trap = cos(θ) * [0.0, 1.0, 0.0] + sin(θ) * [1.0, 0.0, -1.0] / √2
scalar_polarizability(state, state′) = polarizability(state, state′, α .* [1,0,0], ϵ_trap)
tensor_polarizability(state, state′) = polarizability(state, state′, α .* [0,0,1], ϵ_trap)
H = add_to_H(H, :I_scalar, (1e-6 / h) * scalar_polarizability)
H = add_to_H(H, :I_tensor, (1e-6 / h) * tensor_polarizability)

# Add DC Stark effect
const μX = 1e-6 * 1.458 * (1e-21 / c) / h
H = add_to_H(H, :E, (1e2 * μX) * Stark) # 1e2 converts from V/m to V/cm

# Add Zeeman effect
Zeeman_z(state, state′) = Zeeman(state, state′, 0)
H = add_to_H(H, :B_z, gS * (1e-10 * μ_B / h) * Zeeman_z)
;
# Out:
# WARNING: redefinition of constant α. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant θ. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant ϵ_trap. This may fail, cause incorrect answers, or produce other errors.

# %%
H.parameters.E = 25 * 0.3
H.parameters.B_z = 0.01e-6
H.parameters.I_scalar = (0.4/4) * I_trap / (2ε_0 * c)
H.parameters.I_tensor = (0.4/4) * I_trap / (2ε_0 * c)
full_evaluate!(H)
solve!(H)
_, N1_J12_states = subspace(H.states, (N=1, J=1/2))
_, N1_J32_states = subspace(H.states, (N=1, J=3/2))
_, N2_J32_states = subspace(H.states, (N=2, J=3/2))
_, N2_states = subspace(H.states, (N=2,))

# Select only states of the correct parity
# N1_J12_states_Pneg = N1_J12_states[Parity.(N1_J12_states) .== -1]
# N1_J32_states_Pneg = N1_J32_states[Parity.(N1_J32_states) .== -1]
# N2_J32_states_Pneg = N2_J32_states[Parity.(N2_J32_states) .== -1]
# N2_J32_states_Ppos = N2_J32_states[Parity.(N2_J32_states) .== +1]
;

# %%
# |N=1, J=1/2, p=-⟩ -> |N=2, J=3/2, p=-⟩
transitions = compute_transitions(N1_J12_states, N2_J32_states, -1, threshold=1e-5)
transitions = [transitions; compute_transitions(N1_J12_states, N2_J32_states, +1, threshold=1e-5)]
df = transitions_table(transitions)
select!(df, [:State, :N, :F, :M, :State_1, :N_1, :F_1, :M_1, :f, :tdm])
filter!(row -> 39900 < row.f < 39930, df)
df.f .= df.f .- 19985*2

pretty_table(df; nosubheader=true)
# Out:
# ┌───────┬──────┬──────┬───────┬─────────┬──────┬──────┬───────┬──────────┬─────────────┐
# │ State │    N │    F │     M │ State_1 │  N_1 │  F_1 │   M_1 │        f │         tdm │
# ├───────┼──────┼──────┼───────┼─────────┼──────┼──────┼───────┼──────────┼─────────────┤
# │    25 │ 1//1 │ 0//1 │  0//1 │      25 │ 2//1 │ 2//1 │  1//1 │ -54.0206 │  0.00252864 │
# │    19 │ 1//1 │ 1//1 │  0//1 │      19 │ 2//1 │ 1//1 │  1//1 │ -51.7963 │   -0.178114 │
# │    83 │ 1//1 │ 1//1 │  0//1 │      83 │ 2//1 │ 1//1 │  1//1 │ -51.7963 │    0.178114 │
# │    12 │ 1//1 │ 1//1 │ -1//1 │      12 │ 2//1 │ 1//1 │  0//1 │ -51.7677 │   -0.178472 │
# │    76 │ 1//1 │ 1//1 │ -1//1 │      76 │ 2//1 │ 1//1 │  0//1 │ -51.7677 │    0.178472 │
# │     4 │ 1//1 │ 1//1 │  1//1 │       4 │ 2//1 │ 1//1 │  0//1 │  -51.742 │  -0.0958426 │
# │    68 │ 1//1 │ 1//1 │  1//1 │      68 │ 2//1 │ 1//1 │  0//1 │  -51.742 │  -0.0958427 │
# │    20 │ 1//1 │ 1//1 │  0//1 │      20 │ 2//1 │ 1//1 │ -1//1 │ -51.6124 │   -0.138724 │
# │    84 │ 1//1 │ 1//1 │  0//1 │      84 │ 2//1 │ 1//1 │ -1//1 │ -51.6124 │   -0.138724 │
# └───────┴──────┴──────┴───────┴─────────┴──────┴──────┴───────┴──────────┴─────────────┘

# %%
using Plots
vline(df.f, legend=nothing)
# vline!(xs_m30, legend=nothing)
# vline!(xs_70, legend=nothing)
plot!(
    xlim=(-54.5, -51),
    yticks=nothing,
    ylabel="Transition frequency (MHz)",
)

# %%
# |N=1, J=3/2, p=-⟩ -> |N=2, J=3/2, p=-⟩
transitions = compute_transitions(N1_J12_states, N2_J32_states, -1, threshold=1e-7)
transitions = [transitions; compute_transitions(N1_J12_states, N2_J32_states, +1, threshold=1e-7)]
df = transitions_table(transitions)
select!(df, [:State, :N, :F, :M, :State_1, :N_1, :F_1, :M_1, :f, :tdm])
filter!(row -> row.f > 40040, df)
# filter!(row -> 39800 < row.f < 39980, df)
df.f .= df.f .- 19985*2

pretty_table(df; nosubheader=true)
# Out:
# ┌───────┬──────┬──────┬───────┬─────────┬──────┬──────┬───────┬─────────┬──────────────┐
# │ State │    N │    F │     M │ State_1 │  N_1 │  F_1 │   M_1 │       f │          tdm │
# ├───────┼──────┼──────┼───────┼─────────┼──────┼──────┼───────┼─────────┼──────────────┤
# │    29 │ 1//1 │ 0//1 │  0//1 │      29 │ 2//1 │ 2//1 │  1//1 │ 75.1661 │   0.00903215 │
# │    93 │ 1//1 │ 0//1 │  0//1 │      93 │ 2//1 │ 2//1 │  1//1 │ 75.1661 │   0.00903215 │
# │    30 │ 1//1 │ 0//1 │  0//1 │      30 │ 2//1 │ 2//1 │ -1//1 │ 75.3481 │  -0.00803247 │
# │    94 │ 1//1 │ 0//1 │  0//1 │      94 │ 2//1 │ 2//1 │ -1//1 │ 75.3481 │   0.00803248 │
# │    31 │ 1//1 │ 0//1 │  0//1 │      31 │ 2//1 │ 1//1 │  1//1 │ 76.0577 │    0.0065916 │
# │    95 │ 1//1 │ 0//1 │  0//1 │      95 │ 2//1 │ 1//1 │  1//1 │ 76.0577 │   -0.0065916 │
# │    32 │ 1//1 │ 0//1 │  0//1 │      32 │ 2//1 │ 1//1 │ -1//1 │ 76.2371 │  -0.00515663 │
# │    24 │ 1//1 │ 1//1 │  0//1 │      24 │ 2//1 │ 1//1 │ -1//1 │ 77.5924 │   0.00955939 │
# │    88 │ 1//1 │ 1//1 │  0//1 │      88 │ 2//1 │ 1//1 │ -1//1 │ 77.5924 │  -0.00955939 │
# └───────┴──────┴──────┴───────┴─────────┴──────┴──────┴───────┴─────────┴──────────────┘

# %%
using Plots
vline(df.f, legend=nothing)
plot!(
    xlim=(77, 78.5),
    yticks=nothing,
    ylabel="Transition frequency (MHz)",
)

# %%
# |N=1, J=3/2, p=-⟩ -> |N=2, J=1/2, p=-⟩
transitions = compute_transitions(N1_J12_states, N2_states, -1, threshold=1e-7)
transitions = [transitions; compute_transitions(N1_J12_states, N2_states, +1, threshold=1e-7)]
df = transitions_table(transitions)
select!(df, [:State, :N, :F, :M, :State_1, :N_1, :F_1, :M_1, :f, :tdm])
filter!(row -> 39860 > row.f > 39880, df)

pretty_table(df; nosubheader=true)
# Out:
# ┌───────┬───┬───┬───┬─────────┬─────┬─────┬─────┬───┬─────┐
# │ State │ N │ F │ M │ State_1 │ N_1 │ F_1 │ M_1 │ f │ tdm │
# └───────┴───┴───┴───┴─────────┴─────┴─────┴─────┴───┴─────┘

# %% [markdown]
# ### Stark plots

# %%
function H_func!(H, scan_values)
    H.parameters.E = scan_values[1]
    evaluate!(H)
    solve!(H)
    return nothing
end
;

# %%
Es = (0:2:20.0)
scan_params = (
    E = Es,
    );
iterator = Iterators.product
@time scan_values, _ = scan_parameters(deepcopy(H), scan_params, iterator, H_func!, H -> energy.(H.states), n_threads=1)
matrix_values = hcat(values(scan_values)...)'
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
#   0.620059 seconds (80.11 k allocations: 32.171 MiB, 21.35% compilation time)

# %%
Es_rel[end,:]
# Out:
# 120-element Vector{Float64}:
#    9956.824100473452
#    9956.802249351356
#    9956.802249362097
#    9958.180857529625
#    9982.677069916583
#    9982.621667215903
#    9982.621667240704
#    9984.449419280136
#    9984.430215111941
#    9984.430215125794
#    9984.368909983372
#    9984.368910011399
#   10000.355522927053
#       ⋮
#  110140.70507177027
#  110140.70507177839
#  110140.7068034034
#  110141.96385808232
#  110141.96385811023
#  110141.97115773745
#  110141.97115775847
#  110141.9763657594
#  110141.97636577336
#  110141.97948814809
#  110141.97948815525
#  110141.98052854076

# %%
using Plots, LaTeXStrings
Es_rel = matrix_values #.- matrix_values[1,:]'
plot()
plot!(Es, Es_rel[:,5], linewidth=1.5, linecolor=:red)
plot!(Es, Es_rel[:,[6]], linewidth=1.5, linecolor=:blue, alpha=0.5)
plot!(
    legend=nothing,
    xlabel="E-field (V/cm)",
    ylabel="Energy (MHz)",
    labelfontsize=12,
    tickfontsize=12,
    grid=:off,
    box=:on
    )

# %%
using Plots, LaTeXStrings
Es_rel = matrix_values #.- matrix_values[1,:]'
plot()
plot!(Es, Es_rel[:,13], linewidth=1.5, linecolor=:red)
plot!(Es, Es_rel[:,[14,15,16]], linewidth=1.5, linecolor=:blue, alpha=0.5)
plot!(
    legend=nothing,
    xlabel="E-field (V/cm)",
    ylabel="Energy (MHz)",
    labelfontsize=12,
    tickfontsize=12,
    grid=:off,
    box=:on
    )

# %% [markdown]
# ### Zeeman plots

# %%
function H_func!(H, scan_values)
    H.parameters.B_z = scan_values[1]
    evaluate!(H)
    solve!(H)
    return nothing
end
;

# %%
Bs = (0:0.01:1) .* 1e-3
scan_params = (
    B = Bs,
    );
iterator = Iterators.product
@time scan_values, _ = scan_parameters(deepcopy(H), scan_params, iterator, H_func!, H -> energy.(H.states), n_threads=1)
matrix_values = hcat(values(scan_values)...)'
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:09
#   9.629861 seconds (144.19 k allocations: 115.382 MiB, 3.32% compilation time)

# %%
using Plots, LaTeXStrings
Es_rel = matrix_values .- matrix_values[1,:]'
plot(Bs, Es_rel[:,[3,4,9,12,13,16,19,20]], linewidth=1.5, linecolor=:blue, alpha=0.5)
plot!(
    legend=nothing,
    xlabel="B (G)",
    ylabel="Energy (MHz)",
    labelfontsize=12,
    tickfontsize=12,
    grid=:off,
    box=:on
    )

# %% [markdown]
# ### Create table of transitions
