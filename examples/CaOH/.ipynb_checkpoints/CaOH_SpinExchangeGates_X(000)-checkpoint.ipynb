# %%
using QuantumStates, UnitsToValue, DataFrames

# %% [markdown]
# ### Load Hamiltonian

# %%
H = load_from_file("CaOH_X000", "C://Google Drive//github//QuantumStates//Hamiltonians//CaOH//")

# Add AC Stark effect from trap
au = 1.64877727436e-41
w = 2.2e-6; P = @with_unit 0.150 "W"; I_trap = 2P / (π * w^2);
α_par = 186.5
α_perp = 393.2
const α = [(1/3)*(α_par + 2α_perp), 0, (2/3)*(α_par - α_perp)] .* au
const θ = 0.
const ϵ_trap = cos(θ) * [0.0, 1.0, 0.0] + sin(θ) * [1.0, 0.0, -1.0] / √2
scalar_polarizability(state, state′) = polarizability(state, state′, α .* [1,0,0], ϵ_trap)
tensor_polarizability(state, state′) = polarizability(state, state′, α .* [0,0,1], ϵ_trap)
H = add_to_H(H, :I_scalar, (1e-6 / h) * scalar_polarizability)
H = add_to_H(H, :I_tensor, (1e-6 / h) * tensor_polarizability)

# Add DC Stark effect
const μX = 1e-6 * 1.458 * (1e-21 / c) / h
H = add_to_H(H, :E, (1e2 * μX) * Stark) # 1e2 converts from V/m to V/cm

# Add Zeeman effect
Zeeman_z(state, state′) = Zeeman(state, state′, 0)
H = add_to_H(H, :B_z, gS * (1e-10 * μ_B / h) * Zeeman_z)
;
# Out:
# WARNING: redefinition of constant α. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant ϵ_trap. This may fail, cause incorrect answers, or produce other errors.

# %%
H.parameters.E = 0.
H.parameters.B_z = 100.
H.parameters.I_scalar = I_trap
H.parameters.I_tensor = I_trap
full_evaluate!(H)
solve!(H)
;

# %%
QN_bounds = (S = 1/2, I = 1/2, Λ = 0, N = 0:3)
basis_uncoupled = enumerate_states(HundsCaseB_Decoupled, QN_bounds)
states_uncoupled = convert_basis(H.states, basis_uncoupled)
;

# %%
# |0⟩ state
idx_0 = 3
state = states_uncoupled[idx_0]
1e-3 * (1e2 * μX) * 1e6 * d(H.states[idx_0], H.states[idx_0]) |> display
1e-3 * gS * (1e-4 * μ_B / h) * TDM_magnetic(H.states[idx_0], H.states[idx_0], 0) |> display
state |> display
energy(state) |> display
# Out:
# 2.124647999851181e-24 + 0.0im
# 1401.1871790135451 + 0.0im
# State{HundsCaseB_Decoupled}(139.3210816322504, HundsCaseB_Decoupled[HundsCaseB_Decoupled(0.0, 0, 0, 0, 1/2, -1/2, 1/2, -1/2, (N = 0:∞, M_N = 0:0, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 0, 0, 1/2, -1/2, 1/2, 1/2, (N = 0:∞, M_N = 0:0, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 0, 0, 1/2, 1/2, 1/2, -1/2, (N = 0:∞, M_N = 0:0, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 0, 0, 1/2, 1/2, 1/2, 1/2, (N = 0:∞, M_N = 0:0, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 1, -1, 1/2, -1/2, 1/2, -1/2, (N = 0:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 1, -1, 1/2, -1/2, 1/2, 1/2, (N = 0:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 1, -1, 1/2, 1/2, 1/2, -1/2, (N = 0:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 1, -1, 1/2, 1/2, 1/2, 1/2, (N = 0:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 1, 0, 1/2, -1/2, 1/2, -1/2, (N = 0:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 1, 0, 1/2, -1/2, 1/2, 1/2, (N = 0:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5))  …  HundsCaseB_Decoupled(0.0, 0, 3, 1, 1/2, 1/2, 1/2, -1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 1, 1/2, 1/2, 1/2, 1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 2, 1/2, -1/2, 1/2, -1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 2, 1/2, -1/2, 1/2, 1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 2, 1/2, 1/2, 1/2, -1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 2, 1/2, 1/2, 1/2, 1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 3, 1/2, -1/2, 1/2, -1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 3, 1/2, -1/2, 1/2, 1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 3, 1/2, 1/2, 1/2, -1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 3, 1/2, 1/2, 1/2, 1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5))], ComplexF64[-3.641104425900706e-18 + 0.0im, 0.004642135246360487 + 0.0im, 0.9999892252168634 + 0.0im, -1.8110493692779053e-21 + 0.0im, 4.1860686592859645e-46 + 0.0im, -4.730068562318359e-33 + 0.0im, 2.304577145486238e-29 + 0.0im, 3.5281071995779e-27 + 0.0im, -1.6927864343083254e-29 + 0.0im, -2.587382824105598e-27 + 0.0im  …  -3.9590118771916474e-49 + 0.0im, 7.187605392702502e-56 + 0.0im, 6.100493287386001e-49 + 0.0im, -9.49864257814583e-56 + 0.0im, -9.481959929676564e-56 + 0.0im, 0.0 + 0.0im, 2.3267663878531777e-55 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im, 0.0 + 0.0im], 3)
# 139.3210816322504

# %%
# |1⟩ state
idx_1 = 14
state = states_uncoupled[idx_1]
1e-3 * (1e2 * μX) * 1e6 * d(H.states[idx_1], H.states[idx_1]) |> display
1e-3 * gS * (1e-4 * μ_B / h) * TDM_magnetic(H.states[idx_1], H.states[idx_1], 0) |> display
state |> display
energy(state) |> display
# Out:
# 6.710415741498481e-14 + 0.0im
# 1383.6416484293404 + 0.0im
# State{HundsCaseB_Decoupled}(20193.352197002772, HundsCaseB_Decoupled[HundsCaseB_Decoupled(0.0, 0, 0, 0, 1/2, -1/2, 1/2, -1/2, (N = 0:∞, M_N = 0:0, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 0, 0, 1/2, -1/2, 1/2, 1/2, (N = 0:∞, M_N = 0:0, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 0, 0, 1/2, 1/2, 1/2, -1/2, (N = 0:∞, M_N = 0:0, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 0, 0, 1/2, 1/2, 1/2, 1/2, (N = 0:∞, M_N = 0:0, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 1, -1, 1/2, -1/2, 1/2, -1/2, (N = 0:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 1, -1, 1/2, -1/2, 1/2, 1/2, (N = 0:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 1, -1, 1/2, 1/2, 1/2, -1/2, (N = 0:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 1, -1, 1/2, 1/2, 1/2, 1/2, (N = 0:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 1, 0, 1/2, -1/2, 1/2, -1/2, (N = 0:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 1, 0, 1/2, -1/2, 1/2, 1/2, (N = 0:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5))  …  HundsCaseB_Decoupled(0.0, 0, 3, 1, 1/2, 1/2, 1/2, -1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 1, 1/2, 1/2, 1/2, 1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 2, 1/2, -1/2, 1/2, -1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 2, 1/2, -1/2, 1/2, 1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 2, 1/2, 1/2, 1/2, -1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 2, 1/2, 1/2, 1/2, 1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 3, 1/2, -1/2, 1/2, -1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 3, 1/2, -1/2, 1/2, 1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 3, 1/2, 1/2, 1/2, -1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 3, 1/2, 1/2, 1/2, 1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5))], ComplexF64[8.782494091423246e-20 + 0.0im, -1.5487966060536941e-21 + 0.0im, -1.6554432105847378e-21 + 0.0im, -1.7178960469604127e-16 + 0.0im, -4.5955657692913956e-14 + 0.0im, 3.534498995968024e-15 + 0.0im, 3.409059868851967e-14 + 0.0im, -3.0389394340794404e-14 + 0.0im, 4.771862617206505e-15 + 0.0im, -9.86477036348515e-15 + 0.0im  …  1.6333764026272798e-6 + 0.0im, -1.8695226038569756e-17 + 0.0im, -2.5907382849052995e-6 + 0.0im, -8.113929976214729e-18 + 0.0im, -8.007569550775185e-18 + 0.0im, 1.2839114631576582e-31 + 0.0im, -9.68035473140737e-18 + 0.0im, -3.153829156330386e-31 + 0.0im, 7.415480138588109e-36 + 0.0im, 0.0 + 0.0im], 14)
# 20193.352197002772

# %%
# |e⟩ state
idx_e = 13
state = states_uncoupled[idx_e]
1e-3 * (1e2 * μX) * 1e6 * d(H.states[idx_e], H.states[idx_e]) |> display
1e-3 * gS * (1e-4 * μ_B / h) * TDM_magnetic(H.states[idx_e], H.states[idx_e], 0) |> display
state |> display
energy(state) |> display
# Out:
# -2.192455924709686e-13 + 0.0im
# 1382.8290436429807 + 0.0im
# State{HundsCaseB_Decoupled}(20191.849230122356, HundsCaseB_Decoupled[HundsCaseB_Decoupled(0.0, 0, 0, 0, 1/2, -1/2, 1/2, -1/2, (N = 0:∞, M_N = 0:0, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 0, 0, 1/2, -1/2, 1/2, 1/2, (N = 0:∞, M_N = 0:0, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 0, 0, 1/2, 1/2, 1/2, -1/2, (N = 0:∞, M_N = 0:0, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 0, 0, 1/2, 1/2, 1/2, 1/2, (N = 0:∞, M_N = 0:0, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 1, -1, 1/2, -1/2, 1/2, -1/2, (N = 0:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 1, -1, 1/2, -1/2, 1/2, 1/2, (N = 0:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 1, -1, 1/2, 1/2, 1/2, -1/2, (N = 0:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 1, -1, 1/2, 1/2, 1/2, 1/2, (N = 0:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 1, 0, 1/2, -1/2, 1/2, -1/2, (N = 0:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 1, 0, 1/2, -1/2, 1/2, 1/2, (N = 0:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5))  …  HundsCaseB_Decoupled(0.0, 0, 3, 1, 1/2, 1/2, 1/2, -1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 1, 1/2, 1/2, 1/2, 1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 2, 1/2, -1/2, 1/2, -1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 2, 1/2, -1/2, 1/2, 1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 2, 1/2, 1/2, 1/2, -1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 2, 1/2, 1/2, 1/2, 1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 3, 1/2, -1/2, 1/2, -1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 3, 1/2, -1/2, 1/2, 1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 3, 1/2, 1/2, 1/2, -1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 0, 3, 3, 1/2, 1/2, 1/2, 1/2, (N = 0:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5))], ComplexF64[-4.2314096121344946e-17 + 0.0im, -1.754734529679532e-21 + 0.0im, -1.5840888736151293e-21 + 0.0im, -9.81736969640439e-18 + 0.0im, -2.2376397615217733e-15 + 0.0im, 6.314191885828432e-15 + 0.0im, -4.4883326539595426e-14 + 0.0im, 0.013610348602953404 + 0.0im, -4.528040975541612e-14 + 0.0im, 0.005318860483991272 + 0.0im  …  -1.389701438434327e-18 + 0.0im, 5.7252408591737e-19 + 0.0im, 2.2270783155742235e-18 + 0.0im, -7.580797868744533e-19 + 0.0im, -7.559113273880172e-19 + 0.0im, -9.074956217776667e-44 + 0.0im, 1.8567859354596546e-18 + 0.0im, 2.2291926756104956e-43 + 0.0im, -5.2413375206201016e-48 + 0.0im, 0.0 + 0.0im], 13)
# 20191.849230122356

# %%
TDM(H.states[idx_0], H.states[idx_1], 0) |> display
TDM(H.states[idx_0], H.states[idx_e], 0) |> display
TDM(H.states[idx_1], H.states[idx_e], 0) |> display
# Out:
# 4.938053723311904e-13 + 0.0im
# -0.5754052476008387 + 0.0im
# 1.4605482351473249e-16 + 0.0im

# %%
using Plots
hline(energy.(N1_states), legend=nothing)
plot!(
    xticks=nothing,
    ylabel="Energy (MHz)",
)

# %% [markdown]
# Gate is performed by driving $\pi_{1 \rightarrow e}$

# %%
qubit_states = [idx_0, idx_1, idx_e]
;

# %% [markdown]
# ### Stark plots

# %%
function H_func!(H, scan_values)
    H.parameters.E = scan_values[1]
    evaluate!(H)
    solve!(H)
    return nothing
end
;

# %%
Es = (1e-6:0.0001:0.01)
scan_params = (
    E = Es,
    );
iterator = Iterators.product
@time scan_values, tracked_idxs = scan_parameters(deepcopy(H), scan_params, iterator, H_func!, H -> energy.(H.states), n_threads=10)
matrix_values = hcat(values(scan_values)...)'
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
#   0.548836 seconds (289.45 k allocations: 69.141 MiB, 5.89% gc time, 350.26% compilation time)

# %%
using Plots, LaTeXStrings
Es_rel = matrix_values .- matrix_values[1,:]'
plot(Es, 1e6 .* Es_rel[:,idx_0], linewidth=2, linecolor=:blue, alpha=0.5, label="|0⟩")
plot!(Es, 1e6 .* Es_rel[:,idx_1], linewidth=2, linecolor=:green, alpha=0.5, label="|1⟩")
plot!(Es, 1e6 .* Es_rel[:,idx_e], linewidth=2, linecolor=:red, alpha=0.5, label="|e⟩")
plot!(
    xlabel="E-field (V/cm)",
    ylabel="Energy (Hz)",
    labelfontsize=12,
    tickfontsize=12,
    grid=:off,
    box=:on
)

# %% [markdown]
# ### Zeeman plots

# %%
function H_func!(H, scan_values)
    H.parameters.B_z = scan_values[1]
    evaluate!(H)
    solve!(H)
    return nothing
end
;

# %%
Bs = H.parameters.B_z .+ (-1:0.01:1) .* 1e-3
scan_params = (
    B = Bs,
    );
iterator = Iterators.product
@time scan_values, tracked_idxs = scan_parameters(deepcopy(H), scan_params, iterator, H_func!, H -> energy.(H.states), n_threads=10)
matrix_values = hcat(values(scan_values)...)'
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
#   0.691537 seconds (324.94 k allocations: 102.691 MiB, 347.45% compilation time)

# %%
using Plots, LaTeXStrings
Es_rel = matrix_values .- matrix_values[round(Int, end/2),:]'
plot(Bs, 1e6 .* (Es_rel[:,idx_0] .- Es_rel[:,idx_1]), linewidth=2, linecolor=:blue, alpha=0.5, label="|0⟩ - |1⟩")
plot!(Bs, 1e6 .* (Es_rel[:,idx_0] .- Es_rel[:,idx_e]), linewidth=2, linecolor=:green, alpha=0.5, label="|0⟩ - |e⟩")
plot!(Bs, 1e6 .* (Es_rel[:,idx_1] .- Es_rel[:,idx_e]), linewidth=2, linecolor=:red, alpha=0.5, label="|1⟩ - |e⟩")
plot!(
    xlabel="B (G)",
    ylabel="Energy (Hz)",
    labelfontsize=12,
    tickfontsize=12,
    grid=:off,
    box=:on
    )

# %% [markdown]
# ### Trap shift plots

# %%
function H_func!(H, scan_values)
    H.parameters.I_scalar = scan_values[1]
    H.parameters.I_tensor = scan_values[1]
    evaluate!(H)
    solve!(H)
    return nothing
end
;

# %%
Is = (0:0.01:1.0) .* I_trap
scan_params = (
    I = Is,
    );
iterator = Iterators.product
@time scan_values, _ = scan_parameters(deepcopy(H), scan_params, iterator, H_func!, H -> energy.(H.states), n_threads=10)
matrix_values = hcat(values(scan_values)...)'
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00
#   0.234039 seconds (292.40 k allocations: 69.822 MiB, 311.10% compilation time)

# %%
using Plots, LaTeXStrings
Es_rel = matrix_values .- matrix_values[1,:]'
plot(Is, Es_rel[:,qubit_states], linewidth=1.5, linecolor=:blue, alpha=0.5)
plot!(
    legend=nothing,
    xlabel="I",
    ylabel="Energy (MHz)",
    labelfontsize=12,
    tickfontsize=12,
    grid=:off,
    box=:on
    )
