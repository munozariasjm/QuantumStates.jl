# %%
using Revise

# %%
using QuantumStates, UnitsToValue
# Out:
# ┌ Info: Precompiling QuantumStates [17f0441f-15e0-42ae-a101-302633ff8f0f]
# └ @ Base loading.jl:1662

# %%
H0 = load_from_file("CaOH_BendingMode_Hamiltonian", "C://Users//Christian//Google Drive//github//QuantumStates//Hamiltonians//CaOH//")
;

# %% [markdown]
# ### Characterize scalar and tensor trap shifts

# %%
import QuantumStates.polarizability

# %%
w = 25e-6; P = 1.0; I_trap = 2P / (π * w^2);
const α = [3.37471e-39, 0, -1.01809e-39] # 1064 nm
const θ = 0.
const ϵ_trap = cos(θ) * [0.0, 1.0, 0.0] + sin(θ) * [1.0, 0.0, -1.0] / √2
scalar_polarizability(state, state′) = polarizability(state, state′, α .* [1,0,0], ϵ_trap)
tensor_polarizability(state, state′) = polarizability(state, state′, α .* [0,0,1], ϵ_trap)

# H = H0 + H_Stark + H_trap
const μX = 1e-6 * 1.458 * (1e-21 / c) / h
H = add_to_H(H0, :E, (1e2 * μX) * Stark) # 1e2 converts from V/m to V/cm
H = add_to_H(H, :I_scalar, (1e-6 / h) * scalar_polarizability)
H = add_to_H(H, :I_tensor, (1e-6 / h) * tensor_polarizability)
;

# %%
H.parameters.E = 500.
H.parameters.I_scalar = I_trap / (2ε_0 * c)
H.parameters.I_tensor = I_trap / (2ε_0 * c)
full_evaluate!(H)
solve!(H)
M0_idxs, M0_states = subspace(H.states, (N=1, M=0))
;

# %%
QN_bounds = (S = 1/2, I = 1/2, Λ = [-1,1], N = 1:3)
basis_uncoupled = enumerate_states(HundsCaseB_Decoupled, QN_bounds)
N1_states_uncoupled = convert_basis(N1_states, basis_uncoupled)
;

# %%
function H_func!(H, scan_values)
    H.parameters.I_tensor = scan_values[1]
    evaluate!(H)
    solve!(H)
    return nothing
end
;

# %%
N1_states_uncoupled[2]
# Out:
# State{HundsCaseB_Decoupled}(9801.661435022095, HundsCaseB_Decoupled[HundsCaseB_Decoupled(0.0, -1, 1, -1, 1/2, -1/2, 1/2, -1/2, (N = 1:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, -1, 1, -1, 1/2, -1/2, 1/2, 1/2, (N = 1:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, -1, 1, -1, 1/2, 1/2, 1/2, -1/2, (N = 1:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, -1, 1, -1, 1/2, 1/2, 1/2, 1/2, (N = 1:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, -1, 1, 0, 1/2, -1/2, 1/2, -1/2, (N = 1:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, -1, 1, 0, 1/2, -1/2, 1/2, 1/2, (N = 1:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, -1, 1, 0, 1/2, 1/2, 1/2, -1/2, (N = 1:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, -1, 1, 0, 1/2, 1/2, 1/2, 1/2, (N = 1:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, -1, 1, 1, 1/2, -1/2, 1/2, -1/2, (N = 1:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, -1, 1, 1, 1/2, -1/2, 1/2, 1/2, (N = 1:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5))  …  HundsCaseB_Decoupled(0.0, 1, 3, 1, 1/2, 1/2, 1/2, -1/2, (N = 1:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 1, 3, 1, 1/2, 1/2, 1/2, 1/2, (N = 1:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 1, 3, 2, 1/2, -1/2, 1/2, -1/2, (N = 1:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 1, 3, 2, 1/2, -1/2, 1/2, 1/2, (N = 1:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 1, 3, 2, 1/2, 1/2, 1/2, -1/2, (N = 1:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 1, 3, 2, 1/2, 1/2, 1/2, 1/2, (N = 1:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 1, 3, 3, 1/2, -1/2, 1/2, -1/2, (N = 1:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 1, 3, 3, 1/2, -1/2, 1/2, 1/2, (N = 1:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 1, 3, 3, 1/2, 1/2, 1/2, -1/2, (N = 1:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 1, 3, 3, 1/2, 1/2, 1/2, 1/2, (N = 1:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5))], ComplexF64[-1.6462980511502106e-14 + 0.0im, 4.3618843813271995e-13 + 0.0im, -3.545412786708781e-12 + 0.0im, 0.7043557670936702 + 0.0im, 2.0937488114481875e-13 + 0.0im, -0.046354516849399535 + 0.0im, -0.007220715541349593 + 0.0im, -1.3074588413930293e-15 + 0.0im, 0.04094341102613734 + 0.0im, -2.0983140637631426e-15 + 0.0im  …  6.54660127165093e-20 + 0.0im, 3.241714263901175e-20 + 0.0im, -7.608020781935054e-20 + 0.0im, 3.8903596551240865e-21 + 0.0im, 1.0174958090473946e-20 + 0.0im, -2.1684582642647022e-24 + 0.0im, -2.4005751058263804e-20 + 0.0im, 3.001287034057693e-26 + 0.0im, 5.17840560571781e-28 + 0.0im, -4.934615084749862e-32 + 0.0im], 4)

# %%
N1_states_uncoupled[4]
# Out:
# State{HundsCaseB_Decoupled}(9974.492792471396, HundsCaseB_Decoupled[HundsCaseB_Decoupled(0.0, -1, 1, -1, 1/2, -1/2, 1/2, -1/2, (N = 1:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, -1, 1, -1, 1/2, -1/2, 1/2, 1/2, (N = 1:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, -1, 1, -1, 1/2, 1/2, 1/2, -1/2, (N = 1:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, -1, 1, -1, 1/2, 1/2, 1/2, 1/2, (N = 1:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, -1, 1, 0, 1/2, -1/2, 1/2, -1/2, (N = 1:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, -1, 1, 0, 1/2, -1/2, 1/2, 1/2, (N = 1:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, -1, 1, 0, 1/2, 1/2, 1/2, -1/2, (N = 1:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, -1, 1, 0, 1/2, 1/2, 1/2, 1/2, (N = 1:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, -1, 1, 1, 1/2, -1/2, 1/2, -1/2, (N = 1:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, -1, 1, 1, 1/2, -1/2, 1/2, 1/2, (N = 1:∞, M_N = -1:1, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5))  …  HundsCaseB_Decoupled(0.0, 1, 3, 1, 1/2, 1/2, 1/2, -1/2, (N = 1:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 1, 3, 1, 1/2, 1/2, 1/2, 1/2, (N = 1:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 1, 3, 2, 1/2, -1/2, 1/2, -1/2, (N = 1:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 1, 3, 2, 1/2, -1/2, 1/2, 1/2, (N = 1:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 1, 3, 2, 1/2, 1/2, 1/2, -1/2, (N = 1:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 1, 3, 2, 1/2, 1/2, 1/2, 1/2, (N = 1:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 1, 3, 3, 1/2, -1/2, 1/2, -1/2, (N = 1:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 1, 3, 3, 1/2, -1/2, 1/2, 1/2, (N = 1:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 1, 3, 3, 1/2, 1/2, 1/2, -1/2, (N = 1:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5)), HundsCaseB_Decoupled(0.0, 1, 3, 3, 1/2, 1/2, 1/2, 1/2, (N = 1:∞, M_N = -3:3, M_S = -0.5:1.0:0.5, M_I = -0.5:1.0:0.5))], ComplexF64[-1.6548819484947938e-14 + 0.0im, -1.84703188527259e-14 + 0.0im, 1.029101439276499e-12 + 0.0im, -0.039022333139545534 + 0.0im, 1.2296353104248662e-11 + 0.0im, -0.48911095344160305 + 0.0im, -0.5083910325075305 + 0.0im, 1.693067813264869e-11 + 0.0im, 0.027890127129786196 + 0.0im, -9.649766290884018e-13 + 0.0im  …  -2.214051238859247e-17 + 0.0im, -6.0608450622711e-22 + 0.0im, 3.4652936173121334e-17 + 0.0im, -8.870829997813838e-23 + 0.0im, -6.162038557225182e-23 + 0.0im, -4.953305571187206e-24 + 0.0im, 3.266025739907808e-22 + 0.0im, 6.930338084281978e-26 + 0.0im, 1.1744037752084364e-27 + 0.0im, 1.3735214870257756e-31 + 0.0im], 12)

# %%
Is = (0:0.05:1.0) .* (I_trap / (2ε_0 * c))
scan_params = (
    I = Is,
    );
iterator = Iterators.product
@time scan_values, _ = scan_parameters(deepcopy(H), scan_params, iterator, H_func!, H -> energy.(H.states), n_threads=1)
matrix_values = hcat(values(scan_values)...)'
;
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:03
#   3.846414 seconds (238.93 k allocations: 188.203 MiB, 4.09% compilation time)

# %%
using Plots, LaTeXStrings
Es_rel = matrix_values .- matrix_values[1,:]'
plot(Is, Es_rel[:,M0_idxs[1]], linewidth=1.5, linecolor=:blue, alpha=0.5)
plot!(
    legend=nothing, 
    xlabel="I_s (V/cm)",
    ylabel="Energy (MHz)",
    labelfontsize=12,
    tickfontsize=12,
    grid=:off,
    box=:on
    )
